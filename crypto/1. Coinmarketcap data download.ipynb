# %%
from src.coinmarketcap import *

# %%
coins=cmc()

# %%
coins.to_csv('cmc_20210217.csv', index=None)

# %%
coins.head()
# Out:
#      id      name symbol          slug  num_market_pairs  \
# 0     1   Bitcoin    BTC       bitcoin              9682
# 1  1027  Ethereum    ETH      ethereum              5905
# 2   825    Tether   USDT        tether             10661
# 3  6636  Polkadot    DOT  polkadot-new               140
# 4  2010   Cardano    ADA       cardano               230
#
#                  date_added  \
# 0  2013-04-28T00:00:00.000Z
# 1  2015-08-07T00:00:00.000Z
# 2  2015-02-25T00:00:00.000Z
# 3  2020-08-19T00:00:00.000Z
# 4  2017-10-01T00:00:00.000Z
#
#                                                 tags    max_supply  \
# 0  [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1  [mineable, pow, smart-contracts, coinbase-vent...           NaN
# 2  [store-of-value, payments, stablecoin, stablec...           NaN
# 3  [substrate, polkadot, binance-chain, dot-ecosy...           NaN
# 4  [mineable, dpos, pos, platform, research, smar...  4.500000e+10
#
# ...
